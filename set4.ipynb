# %%
# 1. Write a program that demonstrates plotting the Fibonacci sequence with PyLab.
import matplotlib.pyplot as plt

def fibonacci(n):
    fib_sequence = [0, 1]
    for i in range(2, n):
        fib_sequence.append(fib_sequence[-1] + fib_sequence[-2])
    return fib_sequence

n = 10  # Number of Fibonacci numbers to generate
fib_sequence = fibonacci(n)

plt.plot(fib_sequence)
plt.title('Fibonacci Sequence')
plt.xlabel('Index')
plt.ylabel('Fibonacci Number')
plt.show()

# %%
# 2. Create a function that plots the trajectory of a projectile motion.
import numpy as np

def projectile_motion(v0, theta, g=9.81):
    theta_rad = np.radians(theta)
    t_flight = 2 * v0 * np.sin(theta_rad) / g
    t = np.linspace(0, t_flight, num=500)
    x = v0 * np.cos(theta_rad) * t
    y = v0 * np.sin(theta_rad) * t - 0.5 * g * t**2
    return x, y

v0 = 50  # initial velocity in m/s
theta = 45  # launch angle in degrees

x, y = projectile_motion(v0, theta)

plt.plot(x, y)
plt.title('Projectile Motion Trajectory')
plt.xlabel('Distance (m)')
plt.ylabel('Height (m)')
plt.show()

# %%
# 3. Implement the 0/1 knapsack algorithm to solve a simple problem.
def knapsack(weights, values, W):
    n = len(values)
    dp = [[0 for _ in range(W + 1)] for _ in range(n + 1)]

    for i in range(1, n + 1):
        for w in range(W + 1):
            if weights[i-1] <= w:
                dp[i][w] = max(dp[i-1][w], dp[i-1][w-weights[i-1]] + values[i-1])
            else:
                dp[i][w] = dp[i-1][w]

    return dp[n][W]

weights = [2, 3, 4, 5]
values = [3, 4, 5, 6]
W = 5  # Maximum weight capacity of the knapsack

print(knapsack(weights, values, W))
# Out:
# 7

# %%
# 4. Write a dynamic programming solution for finding the longest common subsequence.
def lcs(X, Y):
    m = len(X)
    n = len(Y)
    dp = [[None]*(n+1) for i in range(m+1)]
    
    for i in range(m+1):
        for j in range(n+1):
            if i == 0 or j == 0 :
                dp[i][j] = 0
            elif X[i-1] == Y[j-1]:
                dp[i][j] = dp[i-1][j-1]+1
            else:
                dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    
    return dp[m][n]

X = "AGGTAB"
Y = "GXTXAYB"
print("Length of LCS is ", lcs(X, Y))
# Out:
# Length of LCS is  4

# %%
# 5. Create a program to visualize dynamic programming approaches for the Fibonacci sequence.
def dp_fibonacci(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    
    dp = [0] * (n + 1)
    dp[1] = 1
    
    for i in range(2, n + 1):
        dp[i] = dp[i - 1] + dp[i - 2]
    
    return dp

n = 10  # Number of Fibonacci numbers to generate
fib_sequence = dp_fibonacci(n)

plt.plot(fib_sequence)
plt.title('Dynamic Programming Fibonacci Sequence')
plt.xlabel('Index')
plt.ylabel('Fibonacci Number')
plt.show()

# %%
# 6. Develop a divide-and-conquer algorithm to sort an array.
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        L = arr[:mid]
        R = arr[mid:]
        
        merge_sort(L)
        merge_sort(R)
        
        i = j = k = 0
        
        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1
        
        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1
        
        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1

arr = [12, 11, 13, 5, 6, 7]
merge_sort(arr)
print("Sorted array is: ", arr)
# Out:
# Sorted array is:  [5, 6, 7, 11, 12, 13]

# %%
# 7. Write a Python function that uses memoization to optimize a recursive problem.
def memo_fibonacci(n, memo={}):
    if n in memo:
        return memo[n]
    if n <= 1:
        return n
    memo[n] = memo_fibonacci(n-1, memo) + memo_fibonacci(n-2, memo)
    return memo[n]

n = 10  # nth Fibonacci number
print(f"Fibonacci number {n} is {memo_fibonacci(n)}")
# Out:
# Fibonacci number 10 is 55

# %%
# 8. Create an application that manages a library system with classes for Book and Library.
class Book:
    def __init__(self, title, author, isbn):
        self.title = title
        self.author = author
        self.isbn = isbn

    def __str__(self):
        return f"Book: {self.title}, Author: {self.author}, ISBN: {self.isbn}"

class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)

    def remove_book(self, isbn):
        self.books = [book for book in self.books if book.isbn != isbn]

    def display_books(self):
        for book in self.books:
            print(book)

library = Library()
book1 = Book("The Great Gatsby", "F. Scott Fitzgerald", "9780743273565")
book2 = Book("1984", "George Orwell", "9780451524935")
library.add_book(book1)
library.add_book(book2)
library.display_books()
# Out:
# Book: The Great Gatsby, Author: F. Scott Fitzgerald, ISBN: 9780743273565
# Book: 1984, Author: George Orwell, ISBN: 9780451524935

# %%
# 9. Implement a simple game (e.g., Guess the Number) using branching and loops.
import random

def guess_the_number():
    number_to_guess = random.randint(1, 100)
    guess = None
    attempts = 0

    while guess != number_to_guess:
        guess = int(input("Guess the number (between 1 and 100): "))
        attempts += 1
        if guess < number_to_guess:
            print("Too low!")
        elif guess > number_to_guess:
            print("Too high!")
        else:
            print(f"Congratulations! You guessed the number in {attempts} attempts.")

guess_the_number()
# Out:
# Too low!
# Too low!
# Too low!
# Too low!
# Too low!
# Too low!
# Too low!
# Too high!
# Too high!
# Too low!
# Too low!
# Too low!
# Too low!
# Too low!
# Too low!
# Too low!
# Too low!
# Too low!
# Too high!
# Too high!
# Too high!
# Congratulations! You guessed the number in 22 attempts.

# %%
# 10. Write a Python program that scrapes data from a website and processes it.
import requests
from bs4 import BeautifulSoup

def scrape_website(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Example: Extracting all the headers (h1) from the webpage
    headers = soup.find_all('h1')
    for header in headers:
        print(header.get_text())

url = "https://example.com"
scrape_website(url)
# Out:
# Example Domain
